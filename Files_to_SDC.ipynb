# %%
import numpy as np
import pandas as pd
import json
import sys
import os
import requests
import shutil
import time
from requests.auth import HTTPBasicAuth
from requests import Request, Session

#Directory to parse
directory = "/Users/jjackaeast001/Documents/Projects/Zipline/Receipts/finalpdfs"

#for myFile in os.listdir(directory):
#    if "thresh" in myFile:
#        os.rename(directory+"/"+myFile,directory+"/"+myFile[:-11]+myFile[-4:])

fileCount = 0
    
for myFile in os.listdir(directory):

    print("Posting " + myFile + " ...")

    url = "https://zipline-dev.pwctaxdigital.com/upload"

    headers = {
        'Referer': "https://zipline-dev.pwctaxdigital.com/",
        'Accept': "*/*",
        'Authorization': "Basic c2RjLXVzZXI6NkhjQ1JHQkF3aFhuNzY2Mg=="
    }

    files={
        'file': open(directory+"/"+myFile, 'rb'), 
    }

    response = requests.post(url, files=files, auth=("ta.pentest1@pwc.com","m2gbNn6p5H5VuHxZ"))

    print(response.text)

    time.sleep(10)
    shutil.move(directory+"/"+myFile,directory2+"/"+myFile)
    fileCount+=1
    print(str(fileCount) + " files sent")
    
print("Complete. " + str(fileCount) + " files pushed.")
# Out:
# Posting r_1802177_11023630_1681686.pdf ...
# {"name":"r_1802177_11023630_1681686.pdf","id":"405gzo1tjs5otx8b.pdf"}
# 1 files sent
# Posting r_1821195_11079953_1698529.pdf ...
# {"name":"r_1821195_11079953_1698529.pdf","id":"405gzo1tjs5oucwg.pdf"}
# 2 files sent
# Posting r_1821679_11082442_1699387.pdf ...
# {"name":"r_1821679_11082442_1699387.pdf","id":"405gzo1tjs5ourbu.pdf"}
# 3 files sent
# Posting r_1821261_11080264_1698660.pdf ...
# {"name":"r_1821261_11080264_1698660.pdf","id":"405gzo1tjs5oxb7h.pdf"}
# 4 files sent
# Posting r_1804440_10988093_1671705.pdf ...
# {"name":"r_1804440_10988093_1671705.pdf","id":"405gzo1tjs5oxxh3.pdf"}
# 5 files sent
# Posting r_1805524_10995733_1673751.pdf ...
# {"name":"r_1805524_10995733_1673751.pdf","id":"405gzo1tjs5oyehl.pdf"}
# 6 files sent
# Posting r_1805183_10993553_1673091.pdf ...
# {"name":"r_1805183_10993553_1673091.pdf","id":"405gzo1tjs5oyum8.pdf"}
# 7 files sent
# Posting r_1807790_11007289_1677122.pdf ...
# ...
